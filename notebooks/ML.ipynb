# %%
# !git clone
# Out:
# fatal: You must specify a repository to clone.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     --reject-shallow      don't clone shallow repository
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
# ...

# %%
# !git clone https://github.com/Soma1225/Research.git
# %cd Research
# !ls
# Out:
# Cloning into 'Research'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.
# /content/Research
# README.md

# %%
# !pwd
# !ls -la
# Out:
# /content/Research
# total 24
# drwxr-xr-x 3 root root 4096 Jan  5 05:16 .
# drwxr-xr-x 1 root root 4096 Jan  5 05:16 ..
# drwxr-xr-x 8 root root 4096 Jan  5 05:16 .git
# -rw-r--r-- 1 root root 4688 Jan  5 05:16 .gitignore
# -rw-r--r-- 1 root root   10 Jan  5 05:16 README.md

# %%
# %cd /content/Research
# !git pull
# !ls
# Out:
# /content/Research
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 9 (delta 1), reused 9 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 1.47 KiB | 752.00 KiB/s, done.
# From https://github.com/Soma1225/Research
#    afb26ba..0269edb  main       -> origin/main
# Updating afb26ba..0269edb
# Fast-forward
#  .gitignore         | 21 ++++++++++++++++++
#  README.md          | 63 +++++++++++++++++++++++++++++++++++++++++++++++++++++-
#  notebooks/.gitkeep |  0
#  requirements.txt   |  9 ++++++++
#  src/__init__.py    |  1 +
#  5 files changed, 93 insertions(+), 1 deletion(-)
#  create mode 100644 notebooks/.gitkeep
#  create mode 100644 requirements.txt
#  create mode 100644 src/__init__.py
# notebooks  README.md  requirements.txt	src

# %%
# %cd /content/Research
# !pip -q install -r requirements.txt
# Out:
# /content/Research
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 106.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.2 MB/s eta 0:00:00

# %%
# %%writefile src/hello.py
def main():
    import numpy as np
    print("ok:", np.__version__)
    print("Hello from src/hello.py")

if __name__ == "__main__":
    main()
# Out:
# Writing src/hello.py

# %%
# !python -m src.hello
# Out:
# ok: 2.0.2
# Hello from src/hello.py

# %%
# !mv /content/ML.ipynb /content/Research/notebooks/
# !ls notebooks
# Out:
# mv: cannot stat '/content/ML.ipynb': No such file or directory

# %%
# !ls /content
# Out:
# Research  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive -name "*.ipynb" | head -n 50
# Out:
# /content/drive/MyDrive/Colab Notebooks/qiskit.ipynb
# /content/drive/MyDrive/Colab Notebooks/qulacs_3.ipynb
# /content/drive/MyDrive/Colab Notebooks/2025_10_14_IBM_Quantum.ipynb
# /content/drive/MyDrive/Colab Notebooks/qiskit_simulator.ipynb
# /content/drive/MyDrive/Colab Notebooks/elastic_net.ipynb
# /content/drive/MyDrive/Colab Notebooks/optical_comprehensive_1 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/optical_comprehensive_1.ipynb
# /content/drive/MyDrive/Colab Notebooks/scikitlearn_elasticnet.ipynb
# /content/drive/MyDrive/Colab Notebooks/light_intensity_simulation.ipynb
# /content/drive/MyDrive/Colab Notebooks/light_intensity_simulation_all (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/light_intensity_simulation_all_progress.ipynb
# /content/drive/MyDrive/Colab Notebooks/TCN_hyperparameter_search (2).ipynb
# /content/drive/MyDrive/Colab Notebooks/LSTM_hyperparameter_search_fixed.ipynb
# /content/drive/MyDrive/Colab Notebooks/LSTM_hyperparameter_search (1).ipynb
# ...

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/ML.ipynb" "/content/Research/notebooks/"
# !ls notebooks
# Out:
# ML.ipynb

# %%
# %cd /content/Research
# !git status
# Out:
# /content/Research
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	notebooks/ML.ipynb
# 	src/hello.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# %cd /content/Research
# !git add notebooks/ML.ipynb src/hello.py
# !git status
# Out:
# /content/Research
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   notebooks/ML.ipynb
# 	new file:   src/hello.py

# %%
# !git commit -m "add: ML notebook and hello script"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@4b31b7cf851f.(none)')

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !cp "/content/Research/notebooks/ML.ipynb" "/content/drive/MyDrive/Colab Notebooks/ML.ipynb"
# !cp "/content/Research/src/hello.py" "/content/drive/MyDrive/Colab Notebooks/hello.py"
